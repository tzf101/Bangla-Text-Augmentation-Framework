# %% [markdown]
# # Loading Libraries

# %% [markdown]
# ### Libraries

# %%
# from google.colab import drive
# drive.mount("/content/MyDrive", force_remount=True)

# %%
# !pip install git+https://github.com/csebuetnlp/normalizer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-gk4t0pd1
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-gk4t0pd1
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: emoji==1.4.2 in /home/cse/.local/lib/python3.10/site-packages (from normalizer==0.0.1) (1.4.2)
# Requirement already satisfied: ftfy==6.0.3 in /home/cse/.local/lib/python3.10/site-packages (from normalizer==0.0.1) (6.0.3)
# Requirement already satisfied: regex in /home/cse/.local/lib/python3.10/site-packages (from normalizer==0.0.1) (2023.8.8)
# Requirement already satisfied: wcwidth in /home/cse/.local/lib/python3.10/site-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.6)

# %%
# !pip install sentencepiece
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentencepiece in /home/cse/.local/lib/python3.10/site-packages (0.1.99)

# %%
# !pip install datsets transformers[sentencepiece]
# !pip install sentencepiece

# %%
# !pip install rouge
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rouge in /home/cse/.local/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: six in /home/cse/.local/lib/python3.10/site-packages (from rouge) (1.16.0)

# %%
# !pip install sacrebleu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sacrebleu in /home/cse/.local/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: colorama in /usr/lib/python3/dist-packages (from sacrebleu) (0.4.4)
# Requirement already satisfied: numpy>=1.17 in /home/cse/.local/lib/python3.10/site-packages (from sacrebleu) (1.23.5)
# Requirement already satisfied: tabulate>=0.8.9 in /home/cse/.local/lib/python3.10/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: regex in /home/cse/.local/lib/python3.10/site-packages (from sacrebleu) (2023.8.8)
# Requirement already satisfied: lxml in /home/cse/.local/lib/python3.10/site-packages (from sacrebleu) (4.9.3)
# Requirement already satisfied: portalocker in /home/cse/.local/lib/python3.10/site-packages (from sacrebleu) (2.8.2)

# %%
# !pip install -U sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentence-transformers in /home/cse/.local/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (4.37.2)
# Requirement already satisfied: tqdm in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: numpy in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: nltk in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: Pillow in /usr/lib/python3/dist-packages (from sentence-transformers) (9.0.1)
# Requirement already satisfied: torch>=1.11.0 in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (2.0.1)
# Requirement already satisfied: scikit-learn in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (1.1.3)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: scipy in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (1.11.2)
# Requirement already satisfied: sentencepiece in /home/cse/.local/lib/python3.10/site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (5.4.1)
# Requirement already satisfied: packaging>=20.9 in /home/cse/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.1)
# Requirement already satisfied: filelock in /home/cse/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cse/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /home/cse/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cse/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.9.0)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.99)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.91)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.9.0.58)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.99)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.4.91)
# Requirement already satisfied: triton==2.0.0 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: jinja2 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: sympy in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.101)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.14.3)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.4.0.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (8.5.0.96)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11.0->sentence-transformers) (59.6.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11.0->sentence-transformers) (0.37.1)
# Requirement already satisfied: lit in /home/cse/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.11.0->sentence-transformers) (16.0.6)
# Requirement already satisfied: cmake in /home/cse/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.11.0->sentence-transformers) (3.27.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/cse/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/cse/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.8.8)
# Requirement already satisfied: safetensors>=0.4.1 in /home/cse/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk->sentence-transformers) (8.0.3)
# Requirement already satisfied: joblib in /home/cse/.local/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/cse/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cse/.local/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cse/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.5)
# Requirement already satisfied: mpmath>=0.19 in /home/cse/.local/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)

# %%
# !pip install bert-score
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bert-score in /home/cse/.local/lib/python3.10/site-packages (0.3.13)
# Requirement already satisfied: transformers>=3.0.0 in /home/cse/.local/lib/python3.10/site-packages (from bert-score) (4.37.2)
# Requirement already satisfied: packaging>=20.9 in /home/cse/.local/lib/python3.10/site-packages (from bert-score) (23.1)
# Requirement already satisfied: numpy in /home/cse/.local/lib/python3.10/site-packages (from bert-score) (1.23.5)
# Requirement already satisfied: tqdm>=4.31.1 in /home/cse/.local/lib/python3.10/site-packages (from bert-score) (4.66.1)
# Requirement already satisfied: pandas>=1.0.1 in /home/cse/.local/lib/python3.10/site-packages (from bert-score) (2.2.0)
# Requirement already satisfied: requests in /home/cse/.local/lib/python3.10/site-packages (from bert-score) (2.31.0)
# Requirement already satisfied: matplotlib in /home/cse/.local/lib/python3.10/site-packages (from bert-score) (3.7.2)
# Requirement already satisfied: torch>=1.0.0 in /home/cse/.local/lib/python3.10/site-packages (from bert-score) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cse/.local/lib/python3.10/site-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/cse/.local/lib/python3.10/site-packages (from pandas>=1.0.1->bert-score) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.0.1->bert-score) (2022.1)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (10.2.10.91)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (11.10.3.66)
# Requirement already satisfied: sympy in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (1.12)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (11.7.99)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (10.9.0.58)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (11.7.4.91)
# Requirement already satisfied: typing-extensions in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (4.9.0)
# Requirement already satisfied: jinja2 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (3.1.2)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (2.0.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (11.7.101)
# Requirement already satisfied: networkx in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (3.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (2.14.3)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (11.4.0.1)
# Requirement already satisfied: filelock in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (3.12.2)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/cse/.local/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (8.5.0.96)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.0.0->bert-score) (0.37.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.0.0->bert-score) (59.6.0)
# Requirement already satisfied: cmake in /home/cse/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.0.0->bert-score) (3.27.2)
# Requirement already satisfied: lit in /home/cse/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.0.0->bert-score) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /home/cse/.local/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (2023.8.8)
# Requirement already satisfied: safetensors>=0.4.1 in /home/cse/.local/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/cse/.local/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (0.20.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/cse/.local/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (0.15.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers>=3.0.0->bert-score) (5.4.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cse/.local/lib/python3.10/site-packages (from matplotlib->bert-score) (4.42.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->bert-score) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->bert-score) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/cse/.local/lib/python3.10/site-packages (from matplotlib->bert-score) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cse/.local/lib/python3.10/site-packages (from matplotlib->bert-score) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cse/.local/lib/python3.10/site-packages (from matplotlib->bert-score) (1.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->bert-score) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->bert-score) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cse/.local/lib/python3.10/site-packages (from requests->bert-score) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->bert-score) (3.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cse/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=3.0.0->bert-score) (2023.6.0)
# Requirement already satisfied: six>=1.5 in /home/cse/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cse/.local/lib/python3.10/site-packages (from jinja2->torch>=1.0.0->bert-score) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/cse/.local/lib/python3.10/site-packages (from sympy->torch>=1.0.0->bert-score) (1.3.0)

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from normalizer import normalize
import sentencepiece as spm
import pandas as pd

import sacrebleu
from rouge import Rouge
from sacrebleu import corpus_bleu
from bert_score import score
from sentence_transformers import SentenceTransformer, util
from nltk.translate.bleu_score import sentence_bleu

# %%
import torch
print(torch.cuda.current_device())
print(torch.cuda.device(0))
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
print(torch.cuda.is_available())
# Out:
# 0
# <torch.cuda.device object at 0x7f333ea70310>
# 1
# NVIDIA GeForce RTX 3090
# True

# %% [markdown]
# ### Models

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("../SSD Files/models/paraphrase/banglat5_banglaparaphrase")

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)
print(f'Model is using: {device}')
# Out:
# Model is using: cuda

# %%
tokenizer = AutoTokenizer.from_pretrained("../SSD Files/models/paraphrase/banglat5_banglaparaphrase", use_fast=False)

# %%
local_model_directorysbert = "../SSD Files/models/SBERT/bengali-sentence-bert-nli"

sbert_model = SentenceTransformer(local_model_directorysbert)

# %% [markdown]
# ### Paraphrase function

# %%
def calculate_sbert_score(original, augmented):
    emb1 = sbert_model.encode(original)
    emb2 = sbert_model.encode(augmented)
    cosine_scores = util.pytorch_cos_sim(emb1, emb2)
    sbert_score = cosine_scores.item()
    return sbert_score

# %%
def calculate_scores(original, augmented):
    # BLEU Score
    reference = original
    candidate = augmented
    # bleu_score = sentence_bleu(reference, candidate)
    bleu_score = [sacrebleu.corpus_bleu([aug], [[orig]]).score for aug, orig in zip(augmented, original)]
    # BERTScore
    P, R, F1 = score([augmented], [original], lang="bn", rescale_with_baseline=True)

    # SBERT Score with Cosine Similarity
    emb1 = sbert_model.encode(original)
    emb2 = sbert_model.encode(augmented)
    cosine_scores = util.pytorch_cos_sim(emb1, emb2)
    sbert_score = cosine_scores.item()

    return bleu_score, F1.item(), sbert_score

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import torch

class BanglaParaphraseGenerator:
    def __init__(self):
        self.model = model
        self.model = self.model.to(device)  # Assuming `device` is determined using torch.cuda.is_available()
        self.tokenizer = tokenizer

    def generateParaphrase(self, sentence, max_length=100):
        input_tokens = self.tokenizer(normalize(sentence), return_tensors="pt").input_ids
        input_tokens = input_tokens.to(device)  # Move input tokens to the same device as the model

        generated_tokens = self.model.generate(input_tokens, max_length=max_length)
        decoded_tokens = self.tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]

        return decoded_tokens

# %%
# Define a function to apply paraphrasing
def apply_paraphrasing(row):
    return paraphrase_generator.generateParaphrase(row['original_sentence'])

# %%
def paraphrase_and_evaluate_dataset(file_path, original_col_name, new_col_name):
    # Load the dataset
    df = pd.read_csv(file_path)
    df = df.rename(columns={original_col_name: 'original_sentence'})

    # Apply the text augmentation function
    # Apply the text augmentation function row by row and print progress
    paraphrased_texts = []
    for i, row in df.iterrows():
        augmented_text = apply_paraphrasing(row)
        paraphrased_texts.append(augmented_text)
        if (i + 1) % 100 == 0:
            print(f"{i + 1} rows processed")

    df[new_col_name] = paraphrased_texts

#    # Compute ROUGE scores
#     rouge = Rouge()
#     rouge_scores = []

#     for new_col_name, original_sentence in zip(df[new_col_name], df["original_sentence"]):
#         try:
#             score = rouge.get_scores(new_col_name, original_sentence)[0]
#             rouge_scores.append({
#                 'r1f1': score['rouge-1']['f'],
#                 'r2f1': score['rouge-2']['f'],
#                 'rlf1': score['rouge-l']['f'],
#             })
#         except Exception as e:
#             rouge_scores.append({'r1f1': 0, 'r2f1': 0, 'rlf1': 0})

#     rouge_df = pd.DataFrame(rouge_scores)


#     # Initialize a list to hold SacreBLEU scores
#     sacrebleu_scores = []

#     # Iterate over each row in the DataFrame
#     for index, row in df.iterrows():
#         try:
#             # Calculate the SacreBLEU score for each pair of sentences
#             # SacreBLEU expects a list of hypotheses and a list of lists of references
#             score = sacrebleu.corpus_bleu([row['augmented_sentence']], [[row['original_sentence']]]).score
#             sacrebleu_scores.append(score)
#         except Exception as e:
#             # Append a score of 0 if an error occurs
#             sacrebleu_scores.append(0)

#     # Assign the list of scores to a new column in the DataFrame
#     df["sacrebleu_score"] = sacrebleu_scores


#     # SBERT Score with Cosine Similarity
#     sbert_scores = []

#     # Iterate over each row in the DataFrame
#     for index, row in df.iterrows():
#         try:
#             score = calculate_sbert_score([row['augmented_sentence']], [[row['original_sentence']]])
#             sbert_scores.append(score)
#         except Exception as e:
#             sbert_scores.append(0)

#     df["sbert_score"] = sbert_scores
#     # BERTScore
#     # BERTScore, handling KeyError per row
#     # Assuming you have a function 'calculate_f1_score' for F1 score calculation

#     # # Initialize a list to hold F1 scores
#     # bert_scores_f1 = []

#     # for index, row in df.iterrows():
#     #     try:
#     #         # Calculate the F1 score for each pair of sentences
#     #         # Assuming you have a 'calculate_f1_score' function for this purpose
#     #         _, _, F1 = score([row['augmented_sentence']], [[row['original_sentence']]], lang="bn", rescale_with_baseline=True)
#     #         bert_scores_f1.append(F1.item())  # Assuming F1 is a tensor with a single value
#     #     except KeyError:
#     #         # Handle the exception if needed
#     #         bert_scores_f1.append(0)  # Append 0 as a placeholder for the score in case of an error

#     # # Assign the list of F1 scores to a new column in the DataFrame
#     # df["bert_scores_f1"] = bert_scores_f1


#     # Combine the dataframes
#     result_df = pd.concat([df, rouge_df], axis=1)
    df["method"] = "pp"

    return df

# %% [markdown]
# # Testing

# %%
# Example usage:
input_text = "সঠিক তদন্ত করতে হবে। বিচারের আওতায় আনতে হবে যে এই কাজ টা করেছে।"
paraphrase_generator = BanglaParaphraseGenerator()
output_text = paraphrase_generator.generateParaphrase(input_text)
print(output_text)
# Out:
# সঠিক তদন্ত করা উচিত এবং সেই ব্যক্তিকে বিচারের আওতায় আনা উচিত, যিনি তা করেছেন।

# %% [markdown]
# # Running on Dataset

# %%
file_path = '../evaluation/sentnob/cleaned_original/train.csv'

# %%
import pandas as pd
train = pd.read_csv(file_path)
# Set the display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Print the train dataframe clipped to 10 rows
train.head(5)
# Out:
#                                            sentence1  label
# 0  স্বাস্থ্যবান হতে চাই , আমি বয়সের তুলনায় অনেক ব...      0
# 1                        ভাইয়া নতুন ভিডিও আসে না কেন      0
# 2        সৌরভ গাঙ্গুলী ছাড়া দাদাগিরি কখনো জমে উঠত না      0
# 3  ক্রিকেট কে বাচাতে হলে পাপকে অতিশিগ্রিই তাকেও গ...      2
# 4                          আমিতো সেই ঝালপ্রিয়ো মানুষ      1

# %% [markdown]
# ### eval

# %%
result_df = paraphrase_and_evaluate_dataset(file_path, 'sentence1', 'augmented_sentence')
# Out:
# 100 rows processed
# 200 rows processed
# 300 rows processed
# 400 rows processed
# 500 rows processed
# 600 rows processed
# 700 rows processed
# 800 rows processed
# 900 rows processed
# 1000 rows processed
# 1100 rows processed
# 1200 rows processed
# 1300 rows processed
# 1400 rows processed
# 1500 rows processed
# 1600 rows processed
# 1700 rows processed
# 1800 rows processed
# 1900 rows processed
# 2000 rows processed
# 2100 rows processed
# 2200 rows processed
# 2300 rows processed
# 2400 rows processed
# 2500 rows processed
# 2600 rows processed
# 2700 rows processed
# 2800 rows processed
# 2900 rows processed
# 3000 rows processed
# 3100 rows processed
# 3200 rows processed
# 3300 rows processed
# 3400 rows processed
# 3500 rows processed
# 3600 rows processed
# 3700 rows processed
# 3800 rows processed
# 3900 rows processed
# 4000 rows processed
# 4100 rows processed
# 4200 rows processed
# 4300 rows processed
# 4400 rows processed
# 4500 rows processed
# 4600 rows processed
# 4700 rows processed
# 4800 rows processed
# 4900 rows processed
# 5000 rows processed
# 5100 rows processed
# 5200 rows processed
# 5300 rows processed
# 5400 rows processed
# 5500 rows processed
# 5600 rows processed
# 5700 rows processed
# 5800 rows processed
# 5900 rows processed
# 6000 rows processed
# 6100 rows processed
# 6200 rows processed
# 6300 rows processed
# 6400 rows processed
# 6500 rows processed
# 6600 rows processed
# 6700 rows processed
# 6800 rows processed
# 6900 rows processed
# 7000 rows processed
# 7100 rows processed
# 7200 rows processed
# 7300 rows processed
# 7400 rows processed
# 7500 rows processed
# 7600 rows processed
# 7700 rows processed
# 7800 rows processed
# 7900 rows processed
# 8000 rows processed
# 8100 rows processed
# 8200 rows processed
# 8300 rows processed
# 8400 rows processed
# 8500 rows processed
# 8600 rows processed
# 8700 rows processed
# 8800 rows processed
# 8900 rows processed
# 9000 rows processed
# 9100 rows processed
# 9200 rows processed
# 9300 rows processed
# 9400 rows processed
# 9500 rows processed
# 9600 rows processed
# 9700 rows processed
# 9800 rows processed
# 9900 rows processed
# 10000 rows processed
# 10100 rows processed
# 10200 rows processed
# 10300 rows processed
# 10400 rows processed
# 10500 rows processed
# 10600 rows processed
# 10700 rows processed
# 10800 rows processed
# 10900 rows processed
# 11000 rows processed
# 11100 rows processed
# 11200 rows processed
# 11300 rows processed
# 11400 rows processed
# 11500 rows processed
# 11600 rows processed
# 11700 rows processed
# 11800 rows processed
# 11900 rows processed
# 12000 rows processed
# 12100 rows processed
# 12200 rows processed
# 12300 rows processed
# 12400 rows processed
# 12500 rows processed

# %% [markdown]
# ### view

# %%
# result_df

# %% [markdown]
# ### Saving the dataset

# %%
file_path = '../evaluation/sentnob/augmented/train_100_pp.csv'
result_df.to_csv(file_path, index=False)
